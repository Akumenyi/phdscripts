# %%
import numpy as np 
import scipy as sp 
from datetime import datetime 
import matplotlib.pyplot as plt
import matplotlib as mpl


import pandas as pd

import matplotlib.pyplot as plt
import matplotlib.colors as colors
import scipy.stats
from sklearn.metrics import mean_squared_error
from math import sqrt
import fileinput
import warnings

plt.rcParams['figure.figsize'] = [25,22]
plt.rcParams['font.size'] = 14
plt.rcParams['figure.dpi'] = 600


warnings.filterwarnings("ignore")
get_ipython().magic(u'matplotlib inline')
# %config InlineBackend.figure_format = 'retina'

# %%
#define directories
datadir = '/terra/users/csag/kwesi/research/CMIP5_models/cmip5_smhi/models_som_in/'
plotoutdir = '/terra/users/csag/kwesi/research/CMIP5_models/cmip5_smhi/models_som_in/'

# %%
with open(datadir + 'SAfr_700hpa_era_4x3II.vis', "r") as inpf:
    eravis = inpf.readlines()
eravis = np.array([x.strip().split() for x in eravis[1:]]).astype(float)

eranodes=eravis[:,0]+eravis[:,1]*4

qerrs=[]
for i in range(12):
    ind=np.where(eranodes==i)[0]
    #print(ind.shape)
    qerr=eravis[ind,2]
    qerrs=qerrs+[qerr.mean()]

bounds = np.linspace(32, 47, 31)
norm = colors.BoundaryNorm(boundaries=bounds, ncolors=256)
mmin=32
mmax=47

plt.imshow(np.array(qerrs).reshape(3,4),norm=norm,vmin=mmin,vmax=mmax, cmap=plt.cm.gray)
plt.colorbar()
#plt.show()
#plt.plot(qerrs)
plt.show()
ea = qerrs

# %%
with open(datadir + 'zg700_day_CanESM2_rcp85_r1i1p1_19800101-20131231_SD_lonlat_II.vis', "r") as inpf:
    canvis = inpf.readlines()
canvis = np.array([x.strip().split() for x in canvis[1:]]).astype(float)

cannodes=canvis[:,0]+canvis[:,1]*4

qerrs=[]
for i in range(12):
    ind=np.where(cannodes==i)[0]
    #print(ind.shape)
    qerr=canvis[ind,2]
    qerrs=qerrs+[qerr.mean()]
    
bounds = np.linspace(32, 47, 31)
norm = colors.BoundaryNorm(boundaries=bounds, ncolors=256)
mmin=32
mmax=47

plt.imshow(np.array(qerrs).reshape(3,4),norm=norm,vmin=mmin,vmax=mmax, cmap=plt.cm.gray)
plt.colorbar()
plt.show()
cn = qerrs

# %%
with open(datadir + 'zg700_day_CNRM-CM5_rcp85_r1i1p1_19800101-20131231_SD_lonlat_II.vis', "r") as inpf:
    cnrvis = inpf.readlines()
cnrvis = np.array([x.strip().split() for x in cnrvis[1:]]).astype(float)

cnrnodes=cnrvis[:,0]+cnrvis[:,1]*4

qerrs=[]
for i in range(12):
    ind=np.where(cnrnodes==i)[0]
    qerr=cnrvis[ind,2]
    qerrs=qerrs+[qerr.mean()]
    
bounds = np.linspace(32, 47, 31)
norm = colors.BoundaryNorm(boundaries=bounds, ncolors=256)
mmin=32
mmax=47

plt.imshow(np.array(qerrs).reshape(3,4),norm=norm,vmin=mmin,vmax=mmax, cmap=plt.cm.gray)
plt.colorbar()
plt.show()
cr = qerrs

# %%
with open(datadir + 'zg700_day_GFDL-ESM2M_rcp85_r1i1p1_19800101-20131231_SD_lonlat_II.vis', "r") as inpf:
    gfdvis = inpf.readlines()
gfdvis = np.array([x.strip().split() for x in gfdvis[1:]]).astype(float)

gfdnodes=canvis[:,0]+gfdvis[:,1]*4

qerrs=[]
for i in range(12):
    ind=np.where(gfdnodes==i)[0]
    qerr=gfdvis[ind,2]
    qerrs=qerrs+[qerr.mean()]
    
bounds = np.linspace(32, 47, 31)
norm = colors.BoundaryNorm(boundaries=bounds, ncolors=256)
mmin=32
mmax=47

plt.imshow(np.array(qerrs).reshape(3,4), cmap=plt.cm.gray)
plt.colorbar()
plt.show()
gd = qerrs

# %%
with open(datadir + 'zg700_day_HadGEM2-ES_rcp85_r1i1p1_19800101-20131231_SD_lonlat_II.vis', "r") as inpf:
    hadvis = inpf.readlines()
hadvis = np.array([x.strip().split() for x in hadvis[1:]]).astype(float)

hadnodes=hadvis[:,0]+hadvis[:,1]*4

qerrs=[]
for i in range(12):
    ind=np.where(hadnodes==i)[0]
    qerr=hadvis[ind,2]
    qerrs=qerrs+[qerr.mean()]
    
bounds = np.linspace(32, 47, 31)
norm = colors.BoundaryNorm(boundaries=bounds, ncolors=256)
mmin=32
mmax=47

plt.imshow(np.array(qerrs).reshape(3,4),norm=norm,vmin=mmin,vmax=mmax, cmap=plt.cm.gray)
plt.colorbar()
plt.show()
hd = qerrs

# %%
with open(datadir + 'zg700_day_IPSL-CM5A-LR_rcp85_r1i1p1_19800101-20131231_SD_lonlat_II.vis', "r") as inpf:
    ipsvis = inpf.readlines()
ipsvis = np.array([x.strip().split() for x in ipsvis[1:]]).astype(float)

ipsnodes=ipsvis[:,0]+ipsvis[:,1]*4

qerrs=[]
for i in range(12):
    ind=np.where(ipsnodes==i)[0]
    qerr=ipsvis[ind,2]
    qerrs=qerrs+[qerr.mean()]
    
bounds = np.linspace(32, 47, 31)
norm = colors.BoundaryNorm(boundaries=bounds, ncolors=256)
mmin=32
mmax=47

plt.imshow(np.array(qerrs).reshape(3,4),norm=norm,vmin=mmin,vmax=mmax, cmap=plt.cm.gray)
plt.colorbar()
plt.show()
ip = qerrs

# %%
with open(datadir + 'zg700_day_MIROC-ESM_rcp85_r1i1p1_19800101-20131231_SD_lonlat_II.vis', "r") as inpf:
    mirvis = inpf.readlines()
mirvis = np.array([x.strip().split() for x in mirvis[1:]]).astype(float)

mirnodes=mirvis[:,0]+mirvis[:,1]*4

qerrs=[]
for i in range(12):
    ind=np.where(mirnodes==i)[0]
    qerr=mirvis[ind,2]
    qerrs=qerrs+[qerr.mean()]
    
bounds = np.linspace(24, 56, 21)
norm = colors.BoundaryNorm(boundaries=bounds, ncolors=256)
mmin=24
mmax=56

plt.imshow(np.array(qerrs).reshape(3,4), norm=norm, vmin=mmin, vmax=mmax, cmap=plt.cm.gray)
plt.colorbar()
plt.show()
mi = qerrs

# %%
with open(datadir + 'zg700_day_MPI-ESM-LR_rcp85_r1i1p1_19800101-20131231_SD_lonlat_II.vis', "r") as inpf:
    mpivis = inpf.readlines()
mpivis = np.array([x.strip().split() for x in mpivis[1:]]).astype(float)

mpinodes=mpivis[:,0]+mpivis[:,1]*4

qerrs=[]
for i in range(12):
    ind=np.where(mpinodes==i)[0]
    qerr=mpivis[ind,2]
    qerrs=qerrs+[qerr.mean()]
    
bounds = np.linspace(32, 47, 31)
norm = colors.BoundaryNorm(boundaries=bounds, ncolors=256)
mmin=32
mmax=47

plt.imshow(np.array(qerrs).reshape(3,4),norm=norm,vmin=mmin,vmax=mmax, cmap=plt.cm.gray)
plt.colorbar()
plt.show()
mp = qerrs

# %%
with open(datadir + 'zg700_day_MRI-CGCM3_rcp85_r1i1p1_19800101-20131231_SD_lonlat_II.vis', "r") as inpf:
    mrivis = inpf.readlines()
mrivis = np.array([x.strip().split() for x in mrivis[1:]]).astype(float)

mrinodes=mrivis[:,0]+mrivis[:,1]*4

qerrs=[]
for i in range(12):
    ind=np.where(mrinodes==i)[0]
    qerr=mrivis[ind,2]
    qerrs=qerrs+[qerr.mean()]

bounds = np.linspace(32, 47, 31)
norm = colors.BoundaryNorm(boundaries=bounds, ncolors=256)
mmin=32
mmax=47

plt.imshow(np.array(qerrs).reshape(3,4),norm=norm,vmin=mmin,vmax=mmax, cmap=plt.cm.gray)
plt.colorbar()
plt.show()
mr = qerrs

# %% [markdown]
# qerrors = pd.DataFrame(ea, cn, cr, gd, hd, ip, mi, mp, mr)
# qerrors.set_axis(['ERA','CANESM','CNRM','GFDL','HADGEM','IPSL','MIROC','MPI','MRI'], axis=1, inplace=False)

# %%
ea
# Out:
# [41.263709920634916,
#  41.85507775628626,
#  44.40774207377867,
#  46.63281048304214,
#  39.65287276550999,
#  36.342276310483875,
#  35.396584455958546,
#  39.49961690140845,
#  40.797176470588234,
#  35.2465698399326,
#  35.184503125000006,
#  34.87894418331375]

# %% [markdown]
# with fileinput.input(files=(datadir + '700_new_z.DM.era_intSAfrinv.1980-2013.asc')) as f:
#     for line in f:
#         print(line[:,1])
#         #era = np.array([x.strip().split() for x in f[1:]]).astype(float)

# %%
np.mean(ea), np.mean(cn), np.mean(cr), np.mean(gd), np.mean(hd), np.mean(ip), np.mean(mi), np.mean(mp), np.mean(mr)
# Out:
# (39.26315702382812,
#  36.67212704146791,
#  37.41413078588564,
#  33.503139289818314,
#  34.88944787943062,
#  33.58295036851812,
#  34.5287493912381,
#  36.3237990414355,
#  38.52305944284421)

# %%
#with open(datadir + '700_new_z.DM.era_intSAfrinv.1980-2013.asc', "r") as inpf:
#    era = inpf.readlines()
#era = np.array([x.strip().split() for x in era[1:]]).astype(float)


#rms = sqrt(mean_squared_error(y_actual, y_predicted))

# %% [markdown]
# era = pd.read_csv(datadir + '700_new_z.DM.era_intSAfrinv.1980-2013.asc')
# can = pd.read_csv(datadir + 'zg700_day_CanESM2_rcp85_r1i1p1_19800101-20131231_SD_lonlat.asc')
# cnr = pd.read_csv(datadir + 'zg700_day_CNRM-CM5_rcp85_r1i1p1_19800101-20131231_SD_lonlat.asc')
# gfd = pd.read_csv(datadir + 'zg700_day_GFDL-ESM2M_rcp85_r1i1p1_19800101-20131231_SD_lonlat.asc')
# had = pd.read_csv(datadir + 'zg700_day_HadGEM2-ES_rcp85_r1i1p1_19800101-20131231_SD_lonlat.asc')

# %% [markdown]
# ips = pd.read_csv(datadir + 'zg700_day_IPSL-CM5A-LR_rcp85_r1i1p1_19800101-20131231_SD_lonlat.asc')
# mir = pd.read_csv(datadir + 'zg700_day_MIROC-ESM_rcp85_r1i1p1_19800101-20131231_SD_lonlat.asc')
# mpi = pd.read_csv(datadir + 'zg700_day_MPI-ESM-LR_rcp85_r1i1p1_19800101-20131231_SD_lonlat.asc')
# mri = pd.read_csv(datadir + 'zg700_day_MRI-CGCM3_rcp85_r1i1p1_19800101-20131231_SD_lonlat.asc')
